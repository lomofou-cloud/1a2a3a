# %%
a = 3
print("Life is too short, You need Python")
print("a")
print("123")
# Out:
# Life is too short, You need Python
# a
# 123

# %%
# 작은따옴표
'Python is fun'
# Out:
# 'Python is fun'

# %%
# 큰따옴표 3개 연속
"""life is too short, you need python"""
# Out:
# 'life is too short, you need python'

# %%
# 작은따옴표 3개 연속
'''life is too short,
 you need python'''
# Out:
# 'life is too short, you need python'

# %%
"Python's favorite food is perl"
# Out:
# "Python's favorite food is perl"

# %%
print('"python is very easy" he says')
# Out:
# "python is very easy" he says

# %%
# 역슬래쉬를 이용해서 작은 따옴표와 큰따옴표를 문자열에 포함
food = "python\'s favorite \n is \tperl"
print(food)
# \n 줄을 바꿀때
# \t 탭간격을 줄때
# \\ \를 그대로 사용할때
# \'작은 따옴표를 그대로 표현할때
# Out:
# python's favorite
#  is 	perl

# %%
# 문자열 연산하기
head = "python"
tail = " is fun"
head + tail
# Out:
# 'python is fun'

# %%
a = " Python "
a * 3
# Out:
# ' Python  Python  Python '

# %%
#문자열 길이 구하기
a = "life is too short"
# len("life is too short")
len(a)
# Out:
# 17

# %%
# 문자열 인덱싱
a = "life is too short"
print(a[8])
print(a[-1])
print(a[-2])
# Out:
# t
# t
# r

# %%
#문자열 슬라이싱
a = '''life is too short, you need python'''
a[0:4]
a[12:17]
a[5:]
a[:17]
a[:]
# Out:
# 'life is too short, you need python'

# %%
# 문자열 변수 출력 
day = "four"
print(f"I was sic for {day} days")
# Out:
# I was sic for four days
