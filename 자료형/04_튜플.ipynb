# %%
# 튜플은 어떻게 만들까
t1 = ()
t2 = (1,)
t3 = (1,2,3)
t4 = 1,2,3
t5 = ("a","b",("ab","cd"))

a = list()
b = tuple()
# a = 1,
# b = 2
# c = [1,2,3]
# d = (1,2)
b
# Out:
# ()

# %%
t1 = (1,2,"a","b")

# 튜플 요소값을 삭제하려할때 - 지울수없고 변경도못함
del t1(0)
# Out:
#   Cell In[5], line 4
#     del t1(0)
#         ^
# SyntaxError: cannot delete function call

# %%
t1 = (1,2,"a","b")

# 튜플 요소값을 변경하려 할 때
t1[1] = 4
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 4
#       1 t1 = (1,2,"a","b")
#       3 # 튜플 요소값을 변경하려 할 때
# ----> 4 t1[1] = 4
#
# TypeError: 'tuple' object does not support item assignment

# %%
#인덱싱 하기
t1 = (1,2, "a","b")
t1[2]
# Out:
# 'a'

# %%
#슬라이싱하기
t1 = (1,2, "a","b")
t1[2:]
# Out:
# ('a', 'b')

# %%
#튜플 더하기와 곱하기
t1 = (1,2, "a","b")
t2 = (3,4)
t1 + t2
# Out:
# (1, 2, 'a', 'b', 3, 4)

# %%
# 튜플 곱하기
t2 = (3,4)
t2 * 3
# Out:
# (3, 4, 3, 4, 3, 4)

# %%
#튜플 길이 구하기
t1 = (1,2, "a","b")
len(t1)
# Out:
# 4
