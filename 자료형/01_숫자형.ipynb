# %%
# 정수형
a = 123
b = -178
c = 0
print(a)
[print(b)]
print(c)
type(a)
# Out:
# 123
# -178
# 0
# int

# %%
# 실수형
a = 1.2
b = -3.45
print(a)
print(b)
type(a)
# Out:
# 1.2
# -3.45
# float

# %%
a = 3
b = 4
print(a + b)
print(a - b)
print(a * b)
print(a / b)
# Out:
# 7
# -1
# 12
# 0.75

# %%
# x의 y제곱을 나타내는 ** 연산자
a = 3
b = 4
a ** b
# Out:
# 81

# %%
# 나눗셈 후 나머지를 구하는 % 연산자
print(7 % 3)
print(3 % 2)
# Out:
# 1
# 1

# %%
# 나눗셈 후 몫을 구하는 연산자
print( 7 // 4)
# Out:
# 1

# %%
#복합연산자
a = 1
a += 1
# a = a + 1
# +=
# -=
# *=
# /=
print(a)
# Out:
# 2
