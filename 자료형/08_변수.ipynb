# %%
# 변수는 어떻게 만들까
a = 1
b = "python"
c = [1, 2, 3]

# %%
# 변수명 규칙
# 1. 영문자, 숫자, 언더스코어(_)만 사용 할 수 있다.
a1 = 1
t1 = 2
type_script = 1
typeScript = 1

# 2. 숫자로 시작 할 수 없다.
1t = 1

# 3. 예약어는 사용 할 수 없다.
print
len
False
True
and
break
if
from
a1 = 1
t1 = 2
type_script = 1
typeScript = 1

# 4. 대소 문자를 구분한다.
Abc = 1
abc = 1
# Out:
#   Cell In[4], line 9
#     1t = 1
#     ^
# SyntaxError: invalid decimal literal

# %%
#프린트 고치는법
import builtins
print = builtins.print

# %%
( a , b )= "python","Life"
print(a)
print(b)
# Out:
# python
# Life

# %%
[a ,b] = ["python" , "life"]
print(a)
print(b)
# Out:
# python
# life
